# %%
# Simple character-level prediction using RNN
# 2017-03-30
# 
# 'hello_world'
#
# input:  'hello_worl'
# output: 'ello_world'
# 
# TensorFlow 1.0.1
# ref: https://hunkim.github.io/ml/

import tensorflow as tf
import numpy as np

# %%
# Make input data
char_list = ['h','e','l','o','_','w','r','d']
char_idx = {c: i for i, c in enumerate(char_list)} # character with index
char_data = [char_idx[c] for c in 'hello_world']
char_data_onehot = tf.one_hot(char_data, 
                              depth=len(char_list), 
                              on_value=1., 
                              off_value=0.,
                              axis=1, 
                              dtype=tf.float32)
char_input = char_data_onehot[:-1] # 'hello_worl'
char_output = char_data_onehot[1:] # 'ello_world'
print('char_data:', char_data)
print('char_data_onehot:', char_data_onehot.shape)
print('char_input:', char_input.shape)
print('char_output:', char_output.shape)
# Out:
# char_data: [0, 1, 2, 2, 3, 4, 5, 3, 6, 2, 7]
# char_data_onehot: (11, 8)
# char_input: (10, 8)
# char_output: (10, 8)

# %%
# Set configurations
n_char = len(char_list)
rnn_size = n_char # number of one-hot coding vectors == output size for each cell
n_timestep = 10 # 'hello_worl' --> 'ello_world' (prediction)
batch_size = 1  # one example

# Set RNN
rnn_cell = tf.contrib.rnn.BasicRNNCell(rnn_size)
init_state = tf.zeros([batch_size, rnn_cell.state_size])
input_split = tf.split(value=char_input, num_or_size_splits=n_timestep, axis=0)
outputs, state = tf.contrib.rnn.static_rnn(rnn_cell, input_split, init_state)

# %%
# logits: A 3D Tensor of shape [batch_size x sequence_length x num_decoder_symbols] and dtype float. 
# targets: A 2D Tensor of shape [batch_size x sequence_length] and dtype int.
# weights: A 2D Tensor of shape [batch_size x sequence_length] and dtype float.
# logits = tf.reshape(tf.concat(values=char_output, axis=1), [batch_size, n_timestep, rnn_size])
logits = tf.reshape(outputs, [batch_size, n_timestep, rnn_size])
targets = tf.reshape(char_data[1:], [batch_size, n_timestep]) # target as index
weights = tf.ones((batch_size, n_timestep))

loss = tf.contrib.seq2seq.sequence_loss(logits, targets, weights)
cost = tf.reduce_sum(loss) / batch_size
train_op = tf.train.RMSPropOptimizer(learning_rate = 0.01, decay = 0.9).minimize(cost)

# %%
# Launch the graph in a session
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    for i in range(200):
        _, c = sess.run([train_op, cost])
        result = sess.run(tf.arg_max(logits, 2))
        print('Epoch:', i+1, 'cost:', c, 'raw:', result, '\npredict:',''.join([char_list[t] for t in result[0]]))
# Out:
# Epoch: 1 cost: 2.05467 raw: [[0 3 1 3 6 1 4 4 4 5]]
# predict: hoeore___w
# Epoch: 2 cost: 2.04092 raw: [[0 3 1 3 6 1 4 4 4 5]]
# predict: hoeore___w
# Epoch: 3 cost: 2.02727 raw: [[0 3 1 3 6 1 4 4 4 5]]
# predict: hoeore___w
# Epoch: 4 cost: 2.01374 raw: [[0 3 1 3 6 1 4 4 4 5]]
# predict: hoeore___w
# Epoch: 5 cost: 2.00034 raw: [[0 3 1 3 6 1 4 6 4 6]]
# predict: hoeore_r_r
# Epoch: 6 cost: 1.98706 raw: [[0 3 1 3 6 1 4 6 4 6]]
# predict: hoeore_r_r
# Epoch: 7 cost: 1.97393 raw: [[0 3 1 3 6 1 4 6 4 6]]
# predict: hoeore_r_r
# Epoch: 8 cost: 1.96097 raw: [[0 3 1 3 6 1 4 6 4 6]]
# predict: hoeore_r_r
# Epoch: 9 cost: 1.9482 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 10 cost: 1.93565 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 11 cost: 1.92335 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 12 cost: 1.91131 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 13 cost: 1.89954 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 14 cost: 1.88803 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 15 cost: 1.87678 raw: [[0 3 1 3 6 1 4 6 3 6]]
# predict: hoeore_ror
# Epoch: 16 cost: 1.86577 raw: [[0 3 1 3 4 1 4 6 3 6]]
# predict: hoeo_e_ror
# Epoch: 17 cost: 1.85498 raw: [[0 3 1 3 4 1 4 6 3 6]]
# predict: hoeo_e_ror
# Epoch: 18 cost: 1.84439 raw: [[0 2 1 3 4 1 4 6 3 6]]
# predict: hleo_e_ror
# Epoch: 19 cost: 1.83398 raw: [[0 2 1 3 4 1 4 6 3 6]]
# predict: hleo_e_ror
# Epoch: 20 cost: 1.82373 raw: [[0 2 1 3 4 1 4 6 3 6]]
# predict: hleo_e_ror
# Epoch: 21 cost: 1.81362 raw: [[1 2 1 3 4 1 4 6 3 6]]
# predict: eleo_e_ror
# Epoch: 22 cost: 1.80364 raw: [[1 2 1 3 4 1 4 6 3 6]]
# predict: eleo_e_ror
# Epoch: 23 cost: 1.79377 raw: [[1 2 1 3 4 1 4 6 3 6]]
# predict: eleo_e_ror
# Epoch: 24 cost: 1.784 raw: [[1 2 1 3 4 1 4 6 3 0]]
# predict: eleo_e_roh
# Epoch: 25 cost: 1.77434 raw: [[1 2 1 3 4 1 4 6 3 0]]
# predict: eleo_e_roh
# Epoch: 26 cost: 1.76477 raw: [[1 2 1 3 4 1 4 6 3 0]]
# predict: eleo_e_roh
# Epoch: 27 cost: 1.7553 raw: [[1 2 1 3 4 1 4 6 3 0]]
# predict: eleo_e_roh
# Epoch: 28 cost: 1.74592 raw: [[1 2 1 3 4 1 4 6 3 0]]
# predict: eleo_e_roh
# Epoch: 29 cost: 1.73664 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 30 cost: 1.72745 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 31 cost: 1.71838 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 32 cost: 1.70941 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 33 cost: 1.70057 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 34 cost: 1.69185 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 35 cost: 1.68326 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 36 cost: 1.67481 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 37 cost: 1.6665 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 38 cost: 1.65833 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 39 cost: 1.65031 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 40 cost: 1.64243 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 41 cost: 1.63469 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 42 cost: 1.62709 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 43 cost: 1.61962 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 44 cost: 1.61226 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 45 cost: 1.60502 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 46 cost: 1.59787 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 47 cost: 1.59081 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 48 cost: 1.58381 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 49 cost: 1.57688 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 50 cost: 1.56999 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 51 cost: 1.56313 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 52 cost: 1.55628 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 53 cost: 1.54944 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 54 cost: 1.54259 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 55 cost: 1.53572 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 56 cost: 1.52881 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 57 cost: 1.52185 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 58 cost: 1.51485 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 59 cost: 1.50778 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 60 cost: 1.50063 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 61 cost: 1.49341 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 62 cost: 1.48609 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 63 cost: 1.47868 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 64 cost: 1.47116 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 65 cost: 1.46352 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 66 cost: 1.45576 raw: [[1 2 1 3 4 1 3 6 3 0]]
# predict: eleo_eoroh
# Epoch: 67 cost: 1.44787 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 68 cost: 1.43985 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 69 cost: 1.43167 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 70 cost: 1.42335 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 71 cost: 1.41486 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 72 cost: 1.4062 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 73 cost: 1.39738 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 74 cost: 1.38838 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 75 cost: 1.3792 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 76 cost: 1.36984 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 77 cost: 1.36031 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 78 cost: 1.35061 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 79 cost: 1.34075 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 80 cost: 1.33073 raw: [[1 2 1 3 4 1 3 6 3 7]]
# predict: eleo_eorod
# Epoch: 81 cost: 1.32056 raw: [[1 2 1 3 4 1 3 6 2 7]]
# predict: eleo_eorld
# Epoch: 82 cost: 1.31025 raw: [[1 2 1 3 4 1 3 6 2 7]]
# predict: eleo_eorld
# Epoch: 83 cost: 1.29979 raw: [[1 2 1 3 4 1 3 6 2 7]]
# predict: eleo_eorld
