# %% [markdown]
# # Simple Character-level Language Model using vanilla RNN
# 2017-04-11 jkang
# Python3.5
# TensorFlow1.0.1
#
# - input:  &nbsp;&nbsp;'hello_world_good_morning_see_you_hello_grea'
# - output: 'ello_world_good_morning_see_you_hello_great'
#
# ### Reference:
# - https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py
# - https://github.com/aymericdamien/TensorFlow-Examples
# - https://hunkim.github.io/ml/
#
# ### Comment:
# - 단어 단위가 아닌 문자 단위로 훈련함
# - 하나의 example만 훈련에 사용함
# - Cell의 종류는 BasicRNNCell을 사용함 (첫번째 Reference 참조)
# - dynamic_rnn방식 사용 (기존 tf.nn.rnn보다 더 시간-계산 효율적이라고 함)
# - AdamOptimizer를 사용

# %%
import tensorflow as tf
import numpy as np

# Input/Ouput data
char_raw = 'hello_world_good_morning_see_you_hello_great'
char_list = list(set(char_raw))
char_to_idx = {c: i for i, c in enumerate(char_list)}
idx_to_char = {i: c for i, c in enumerate(char_list)}
char_data = [char_to_idx[c] for c in char_raw]
char_data_one_hot = tf.one_hot(char_data, depth=len(
    char_list), on_value=1., off_value=0., axis=1, dtype=tf.float32)
char_input = char_data_one_hot[:-1, :]  # 'hello_world_good_morning_see_you_hello_grea'
char_output = char_data_one_hot[1:, :]  # 'ello_world_good_morning_see_you_hello_great'
with tf.Session() as sess:
    char_input = char_input.eval()
    char_output = char_output.eval()

# %%
# Learning parameters
learning_rate = 0.001
max_iter = 200

# Network Parameters
n_input_dim = char_input.shape[1]
n_input_len = char_input.shape[0]
n_output_dim = char_output.shape[1]
n_output_len = char_output.shape[0]
n_hidden = 100

# TensorFlow graph
# (batch_size) x (time_step) x (input_dimension)
x = tf.placeholder(tf.float32, [1, None, n_input_dim])
# (batch_size) x (time_step) x (output_dimension)
y = tf.placeholder(tf.float32, [1, None, n_output_dim])

# Parameters
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_output_dim], seed=1))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_output_dim], seed=1))
}

# RNN-cell
def RNN(inputs, weights, biases):
    # Reshape to (time_step) x (batch_size) x (input_dimension)
    inputs = tf.transpose(inputs, [1, 0, 2])
    # Reshape to (time_step)*(batch_size) x (input_dimension)
    inputs = tf.reshape(inputs, [-1, n_input_dim])
    # Split to get a list of time_step tensors of shape (batch_size, input_dimension)
    # final 'inputs' is a list of n_input_len elements
    # (=number of frames)
    inputs = tf.split(value=inputs, num_or_size_splits=n_input_len, axis=0)

    rnn = tf.contrib.rnn.BasicRNNCell(n_hidden)
    outputs, states = tf.nn.dynamic_rnn(rnn, x, dtype=tf.float32)
    return tf.matmul(outputs[-1], weights['out']) + biases['out']


pred = RNN(x, weights, biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Learning
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_x = char_input.reshape((1, char_input.shape[0], n_input_dim))
    train_y = char_output.reshape((1, char_output.shape[0], n_output_dim))
    for i in range(max_iter):
        _, loss, p = sess.run([optimizer, cost, pred],
                              feed_dict={x: train_x, y: train_y})
        pred_out = np.argmax(p, axis=1)
        print('Epoch: {:>4}'.format(i + 1), '/', str(max_iter),
              'Cost: {:4f}'.format(loss), 'Predict:', ''.join([idx_to_char[i] for i in pred_out]))
# Out:
# Epoch:    1 / 200 Cost: 5.869480 Predict: uyydtyywhhtwrytw_gmmh_niymytgwtm_tnmydyygw_
# Epoch:    2 / 200 Cost: 4.992157 Predict: uyydtyydhhtgrttw_imth_niametywtm_tnmyddrre_
# Epoch:    3 / 200 Cost: 4.334015 Predict: uyydtdydhhtgwrdw_imt__giayytywtm__nmytdrra_
# Epoch:    4 / 200 Cost: 3.790873 Predict: uyydtdyrthtgwrdw_imto_grayytyttwh_ltdtdrra_
# Epoch:    5 / 200 Cost: 3.330036 Predict: uyydtsrrdhtgwrdh_imto_grheytyttwhaltdtdrra_
# Epoch:    6 / 200 Cost: 2.930901 Predict: uyedtsrrdhtgwrdhmimtoygrheyuyttwhaledtdrrat
# Epoch:    7 / 200 Cost: 2.576494 Predict: uyedtsrrdrtgwrdhmirtoygrheyuywtwhaleotgrrat
# Epoch:    8 / 200 Cost: 2.255446 Predict: uyemtsordrtgnrdwmir_oygrhey_ywgwhaleotgrrat
# Epoch:    9 / 200 Cost: 1.961200 Predict: uyemtsordrtgrrdwmer_oygrsey_y_gwhallotgrrat
# Epoch:   10 / 200 Cost: 1.691601 Predict: uyemu_ordrogrrdwmer_mygrsey_y_g_hallodgrrat
# Epoch:   11 / 200 Cost: 1.449279 Predict: uyeou_ordrogrrd_mor_mygrsee_y_g_hello_great
# Epoch:   12 / 200 Cost: 1.239078 Predict: uyeou_ordr_grod_mor_mng_see_y_h_hello_great
# Epoch:   13 / 200 Cost: 1.061817 Predict: uyeou_ordm_grod_mor_mng_see_yru_hello_great
# Epoch:   14 / 200 Cost: 0.913871 Predict: uyeou_orlm_grod_mor_mng_see_you_hello_great
# Epoch:   15 / 200 Cost: 0.791946 Predict: uyeo__orld_good_mor_mng_see_you_hello_great
# Epoch:   16 / 200 Cost: 0.693078 Predict: uyeo__orld_good_mor_ing_see_you_hello_great
# Epoch:   17 / 200 Cost: 0.613038 Predict: uyeo__orld_good_morying_see_you_hello_goeat
# Epoch:   18 / 200 Cost: 0.546844 Predict: uyeo__orld_good_morying_see_you_hello_goeat
# Epoch:   19 / 200 Cost: 0.490269 Predict: uylo__orld_good_morying_see_you_hello_goeat
# Epoch:   20 / 200 Cost: 0.440795 Predict: uylo__orld_good_morning_see_you_hello_great
# Epoch:   21 / 200 Cost: 0.397583 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   22 / 200 Cost: 0.360661 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   23 / 200 Cost: 0.329859 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   24 / 200 Cost: 0.304393 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   25 / 200 Cost: 0.283206 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   26 / 200 Cost: 0.265338 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   27 / 200 Cost: 0.249988 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   28 / 200 Cost: 0.236478 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   29 / 200 Cost: 0.224265 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   30 / 200 Cost: 0.212991 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   31 / 200 Cost: 0.202471 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   32 / 200 Cost: 0.192609 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   33 / 200 Cost: 0.183320 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   34 / 200 Cost: 0.174511 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   35 / 200 Cost: 0.166095 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:   36 / 200 Cost: 0.158010 Predict: umlo_world_good_morning_see_you_hello_great
# Epoch:
Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  123 / 200 Cost: 0.007622 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  124 / 200 Cost: 0.007500 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  125 / 200 Cost: 0.007381 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  126 / 200 Cost: 0.007266 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  127 / 200 Cost: 0.007155 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  128 / 200 Cost: 0.007047 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  129 / 200 Cost: 0.006943 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  130 / 200 Cost: 0.006841 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  131 / 200 Cost: 0.006742 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  132 / 200 Cost: 0.006646 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  133 / 200 Cost: 0.006553 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  134 / 200 Cost: 0.006462 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  135 / 200 Cost: 0.006374 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  136 / 200 Cost: 0.006288 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  137 / 200 Cost: 0.006205 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  138 / 200 Cost: 0.006123 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  139 / 200 Cost: 0.006043 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  140 / 200 Cost: 0.005966 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  141 / 200 Cost: 0.005890 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  142 / 200 Cost: 0.005816 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  143 / 200 Cost: 0.005744 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  144 / 200 Cost: 0.005674 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  145 / 200 Cost: 0.005605 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  146 / 200 Cost: 0.005538 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  147 / 200 Cost: 0.005472 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  148 / 200 Cost: 0.005407 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  149 / 200 Cost: 0.005345 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  150 / 200 Cost: 0.005283 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  151 / 200 Cost: 0.005223 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  152 / 200 Cost: 0.005164 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  153 / 200 Cost: 0.005106 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  154 / 200 Cost: 0.005049 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  155 / 200 Cost: 0.004994 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  156 / 200 Cost: 0.004939 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  157 / 200 Cost: 0.004886 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  158 / 200 Cost: 0.004834 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  159 / 200 Cost: 0.004782 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  160 / 200 Cost: 0.004732 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  161 / 200 Cost: 0.004683 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  162 / 200 Cost: 0.004634 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  163 / 200 Cost: 0.004586 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  164 / 200 Cost: 0.004540 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  165 / 200 Cost: 0.004494 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  166 / 200 Cost: 0.004449 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  167 / 200 Cost: 0.004405 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  168 / 200 Cost: 0.004361 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  169 / 200 Cost: 0.004318 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  170 / 200 Cost: 0.004276 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  171 / 200 Cost: 0.004235 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  172 / 200 Cost: 0.004194 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  173 / 200 Cost: 0.004154 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  174 / 200 Cost: 0.004115 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  175 / 200 Cost: 0.004077 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  176 / 200 Cost: 0.004039 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  177 / 200 Cost: 0.004001 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  178 / 200 Cost: 0.003964 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  179 / 200 Cost: 0.003928 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  180 / 200 Cost: 0.003893 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  181 / 200 Cost: 0.003858 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  182 / 200 Cost: 0.003823 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  183 / 200 Cost: 0.003789 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  184 / 200 Cost: 0.003756 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  185 / 200 Cost: 0.003723 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  186 / 200 Cost: 0.003690 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  187 / 200 Cost: 0.003658 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  188 / 200 Cost: 0.003627 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  189 / 200 Cost: 0.003595 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  190 / 200 Cost: 0.003565 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  191 / 200 Cost: 0.003535 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  192 / 200 Cost: 0.003505 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  193 / 200 Cost: 0.003476 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  194 / 200 Cost: 0.003447 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  195 / 200 Cost: 0.003418 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  196 / 200 Cost: 0.003390 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  197 / 200 Cost: 0.003362 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  198 / 200 Cost: 0.003335 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  199 / 200 Cost: 0.003308 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  200 / 200 Cost: 0.003282 Predict: ello_world_good_morning_see_you_hello_great

# %% [markdown]
# ### Result:
# - 대략 23번째 Epoch에서부터 이미 첫번째 단어 (hello)를 제외하고 모두 제대로 예측함
# - 67번째 Epoch에 이르러서 모든 연쇄를 정확히 예측함
# - LSTM의 경우보다 예측을 더 빨리 (Epoch 비교시) 잘 해냄 (Cost 비교시)
