# %% [markdown]
# # Simple Character-level Language Model using vanilla RNN
# 2017-04-11 jkang
# Python3.5
# TensorFlow1.0.1
#
# - input:  &nbsp;&nbsp;'hello_world_good_morning_see_you_hello_grea'
# - output: 'ello_world_good_morning_see_you_hello_great'
#
# ### Reference:
# - https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py
# - https://github.com/aymericdamien/TensorFlow-Examples
# - https://hunkim.github.io/ml/
#
# ### Comment:
# - 단어 단위가 아닌 문자 단위로 훈련함
# - 하나의 example만 훈련에 사용함
# - Cell의 종류는 BasicRNNCell을 사용함 (첫번째 Reference 참조)
# - dynamic_rnn방식 사용 (기존 tf.nn.rnn보다 더 시간-계산 효율적이라고 함)
# - AdamOptimizer를 사용

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Input/Ouput data
char_raw = 'hello_world_good_morning_see_you_hello_great'
char_list = list(set(char_raw))
char_to_idx = {c: i for i, c in enumerate(char_list)}
idx_to_char = {i: c for i, c in enumerate(char_list)}
char_data = [char_to_idx[c] for c in char_raw]
char_data_one_hot = tf.one_hot(char_data, depth=len(
    char_list), on_value=1., off_value=0., axis=1, dtype=tf.float32)
char_input = char_data_one_hot[:-1, :]  # 'hello_world_good_morning_see_you_hello_grea'
char_output = char_data_one_hot[1:, :]  # 'ello_world_good_morning_see_you_hello_great'
with tf.Session() as sess:
    char_input = char_input.eval()
    char_output = char_output.eval()

# %%
# Learning parameters
learning_rate = 0.001
max_iter = 200

# Network Parameters
n_input_dim = char_input.shape[1]
n_input_len = char_input.shape[0]
n_output_dim = char_output.shape[1]
n_output_len = char_output.shape[0]
n_hidden = 100

# TensorFlow graph
# (batch_size) x (time_step) x (input_dimension)
x_data = tf.placeholder(tf.float32, [1, None, n_input_dim])
# (batch_size) x (time_step) x (output_dimension)
y_data = tf.placeholder(tf.float32, [1, None, n_output_dim])

# Parameters
weights = {
    'out': tf.Variable(tf.truncated_normal([n_hidden, n_output_dim]))
}
biases = {
    'out': tf.Variable(tf.truncated_normal([n_output_dim]))
}

# %%
def RNN(x, weights, biases):
    cell = tf.contrib.rnn.BasicRNNCell(n_hidden) # Make RNNCell
    outputs, states = tf.nn.dynamic_rnn(cell, x, time_major=False, dtype=tf.float32)
    '''
    **Notes on tf.nn.dynamic_rnn**

    - 'x' can have shape (batch)x(time)x(input_dim), if time_major=False or 
                         (time)x(batch)x(input_dim), if time_major=True
    - 'outputs' can have the same shape as 'x'
                         (batch)x(time)x(input_dim), if time_major=False or 
                         (time)x(batch)x(input_dim), if time_major=True
    - 'states' is the final state, determined by batch and hidden_dim
    '''
    
    # outputs[-1] is outputs for the last example in the mini-batch
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

def softmax(x):
    rowmax = np.max(x, axis=1)
    x -= rowmax.reshape((x.shape[0] ,1)) # for numerical stability
    x = np.exp(x)
    sum_x = np.sum(x, axis=1).reshape((x.shape[0],1))
    return x / sum_x

pred = RNN(x_data, weights, biases)
cost = tf.reduce_mean(tf.squared_difference(pred, y_data))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Learning
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    x_train = char_input.reshape((1, char_input.shape[0], n_input_dim))
    y_train = char_output.reshape((1, char_output.shape[0], n_output_dim))
    for i in range(max_iter):
        _, loss, p = sess.run([optimizer, cost, pred],
                              feed_dict={x_data: x_train, y_data: y_train})
        if i is max_iter-1:
            pred_act = softmax(p)
        pred_out = np.argmax(p, axis=1)
        print('Epoch: {:>4}'.format(i + 1), '/', str(max_iter),
              'Cost: {:4f}'.format(loss), 'Predict:', ''.join([idx_to_char[i] for i in pred_out]))
# Out:
# Epoch:    1 / 200 Cost: 4.072559 Predict: yyoe__ry__y_tg___ty_rery_yut_o_y__ta_h_e_mi
# Epoch:    2 / 200 Cost: 3.208630 Predict: yyoe__ry__y_tg___ty_rery_yut_o_y__ta_u___mi
# Epoch:    3 / 200 Cost: 2.655901 Predict: yyoe__ty__y_tg___ty_rnry_out_t_y__ta_u_tgyi
# Epoch:    4 / 200 Cost: 2.253459 Predict: yyoe__ty__y_tg__gty_rnoy_out_t_y_sta_u_tgri
# Epoch:    5 / 200 Cost: 1.943071 Predict: yyoe__gy__y_tg__gty_gnoy_out_t_y_sta_u_tgri
# Epoch:    6 / 200 Cost: 1.695334 Predict: yyoe__gy__y_tg__gty_gnoy_out_e_y_staeu_tgri
# Epoch:    7 / 200 Cost: 1.492804 Predict: yyoe__gr_ry_tgw_ity_gnoy_out_e_y_staeu_tgri
# Epoch:    8 / 200 Cost: 1.323567 Predict: yyoe__gr_ry_tgw_itn_gnoy_uuu_e_y_staeu_tgri
# Epoch:    9 / 200 Cost: 1.179332 Predict: yyoe__grnry_tgw_itn_gnoy_uuu_emw_staew_gari
# Epoch:   10 / 200 Cost: 1.054854 Predict: yyoe__grnry_tgw_itnmgnry_uuu_emw_staew_gari
# Epoch:   11 / 200 Cost: 0.947066 Predict: yyoe__grnrd_tgw_itnmgnry_uuu_emw_snaew_gari
# Epoch:   12 / 200 Cost: 0.853859 Predict: yyoe__grnrd_tgw_itnmgngn_urumeml_snaew_gari
# Epoch:   13 / 200 Cost: 0.773021 Predict: yyaew_grnrd_tgw_itmmgngn_urumomlosnaew_gari
# Epoch:   14 / 200 Cost: 0.702121 Predict: yyaewsgrdrdwtgw_itmmrngn_urumomwosnaewsgari
# Epoch:   15 / 200 Cost: 0.639668 Predict: yyeewsgrdrdwtgr_itmmrngn_urumomwoswaewsgari
# Epoch:   16 / 200 Cost: 0.586008 Predict: yyeewsgrdrdwtgwditrmrngn_urumomwoswaewsgors
# Epoch:   17 / 200 Cost: 0.541961 Predict: yyeewsgrdrdwtgwdrtrmrngn_urumomwoswaewsgors
# Epoch:   18 / 200 Cost: 0.506353 Predict: yyeewsgrdrdwtgwdrtrdrngn_ueumomwoswaewsgors
# Epoch:   19 / 200 Cost: 0.475835 Predict: yyeewsgrdrdwtgwdrtrdrngy_ueumomwowwaewsgors
# Epoch:   20 / 200 Cost: 0.447385 Predict: yyeewsgrdrdwtgwddtrdrngt_ueumomwowwaewsgors
# Epoch:   21 / 200 Cost: 0.420121 Predict: yyeewsgrdrdwtgw_dtrdrngt_ueumomwowwlewsgors
# Epoch:   22 / 200 Cost: 0.394467 Predict: yyeewsgrdrdwdgw_dtrdgngt_ueumomwowwlewsgows
# Epoch:   23 / 200 Cost: 0.370549 Predict: yyeew_grdrdwdgw_dtrdgngt_ueumomwowwlewsgows
# Epoch:   24 / 200 Cost: 0.348074 Predict: eyeew_grdrdwdgm_dtrdgngt_ueumomwowwlewsgows
# Epoch:   25 / 200 Cost: 0.327091 Predict: eyeew_grdrdwogm_dtrdgng__ueumomwowwlewsuows
# Epoch:   26 / 200 Cost: 0.307944 Predict: eyeew_grdodeogm_dtrdgng__yeumoowowwlewsuows
# Epoch:   27 / 200 Cost: 0.290658 Predict: eyeew_hrdodeogm_dtrdgng__yeumoorowalewsuows
# Epoch:   28 / 200 Cost: 0.274854 Predict: eyeew_hrdodeorm_dtrngng__oeumoorowalewsuows
# Epoch:   29 / 200 Cost: 0.260135 Predict: eyle__hrdodeorm_dtrngng__oeuooorowalowsuows
# Epoch:   30 / 200 Cost: 0.246343 Predict: eyle__hrdodeorm_dtrngng__oeuooorowalowsuows
# Epoch:   31 / 200 Cost: 0.233474 Predict: eyle__hrdodeorm_dtrngng__oeuooowowdlowsuows
# Epoch:   32 / 200 Cost: 0.221483 Predict: eylo__hrdodeorm_dtrngng__oeuooowowdlowguowt
# Epoch:   33 / 200 Cost: 0.210229 Predict: eylo_mhrdodeorm_dtrngng__oeuooowowdlo_gsowt
# Epoch:   34 / 200 Cost: 0.199600 Predict: eylo_mhrlodeorm_itrngng__oeuooowowdlo_gsowt
# Epoch:   35 / 200 Cost: 0.189617 Predict: eylo_mhrlodeorm_itrngng__oeuooowoadlo_gsoat
# Epoch:   36 / 200 Cost: 0.180360 Predict: ealo_mhrlodeorm_itrngng__oeumoowoadlo_gsoat
# Epoch:   37 / 200 Cost: 0.171827 Predict: ealo_mhrlodeorm_itrngng__oeumoow_adlo_gsoat
# Epoch:   38 / 200 Cost: 0.163906 Predict: ealo_mhrlodeorm_itrngng__oeumoow_adlo_gsoat
# Epoch:   39 / 200 Cost: 0.156467 Predict: ealo_mhrlodeorm_itrngng__oeumoow_allo_gseat
# Epoch:   40 / 200 Cost: 0.149461 Predict: ealo_mhrlodeorm_itrngng__oeumoowhallo_gseat
# Epoch:   41 / 200 Cost: 0.142899 Predict: ealo_mhrlodeorm_rtrnhng__oeumoowhallo_gseat
# Epoch:   42 / 200 Cost: 0.136754 Predict: ealo_mhrlddeorm_rtrning__deumouwhallo_gseat
# Epoch:   43 / 200 Cost: 0.130929 Predict: ealo_mhrld_gorm_mtrning__deumouwhwllo_gseat
# Epoch:   44 / 200 Cost: 0.125348 Predict: ealo_mhrld_gorm_mtrning_sdeumouwhwllo_gseat
# Epoch:   45 / 200 Cost: 0.120014 Predict: ealo_mhrld_gorm_mtrning_sdeumouwhwllo_gseat
# Epoch:   46 / 200 Cost: 0.114970 Predict: ealo_mhrld_gorm_mtrning_syeumouwhwllo_gseat
# Epoch:   47 / 200 Cost: 0.110219 Predict: ealo_mhrld_gorm_mtrning_syeumou_hwllo_gseat
# Epoch:   48 / 200 Cost: 0.105729 Predict: ealo_whrld_gorm_mtrning_syeumou_hwllo_gseat
# Epoch:   49 / 200 Cost: 0.101490 Predict: ealo_whrld_goom_mtrning_syeumou_hwllo_gseat
# Epoch:   50 / 200 Cost: 0.097525 Predict: ealo_whrld_goom_morning_syeumou_hwllo_gseat
# Epoch:   51 / 200 Cost: 0.093843 Predict: ealo_whrld_goom_morning_sdeumou_hwllo_gseat
# Epoch:   52 / 200 Cost: 0.090399 Predict: ealo_whrld_goom_morning_sdeumou_hwllo_gseat
# Epoch:   53 / 200 Cost: 0.087122 Predict: ealo_whrld_goom_morning_sde_mou_hwllo_gseat
# Epoch:   54 / 200 Cost: 0.083979 Predict: ealo_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   55 / 200 Cost: 0.080980 Predict: ealo_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   56 / 200 Cost: 0.078122 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   57 / 200 Cost: 0.075376 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   58 / 200 Cost: 0.072739 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   59 / 200 Cost: 0.070235 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   60 / 200 Cost: 0.067873 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   61 / 200 Cost: 0.065637 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   62 / 200 Cost: 0.063518 Predict: ello_whrld_goom_morning_see_mou_hwllo_gseat
# Epoch:   63 / 200 Cost: 0.061518 Predict: ello_whrld_goom_morning_see_you_hwllo_gseat
# Epoch:   64 / 200 Cost: 0.059622 Predict: ello_whrld_goom_morning_see_you_hwllo_gseat
# Epoch:   65 / 200 Cost: 0.057803 Predict: ello_whrld_goom_morning_see_you_hwllo_gseat
# Epoch:   66 / 200 Cost: 0.056048 Predict: ello_whrld_goom_morning_see_you_hwllo_gseat
# Epoch:   67 / 200 Cost: 0.054360 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   68 / 200 Cost: 0.052737 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   69 / 200 Cost: 0.051167 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   70 / 200 Cost: 0.049651 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   71 / 200 Cost: 0.048198 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   72 / 200 Cost: 0.046811 Predict: ello_whrld_goom_morning_see_you_hello_gseat
# Epoch:   73 / 200 Cost: 0.045481 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   74 / 200 Cost: 0.044202 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   75 / 200 Cost: 0.042971 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   76 / 200 Cost: 0.041784 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   77 / 200 Cost: 0.040640 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   78 / 200 Cost: 0.039535 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   79 / 200 Cost: 0.038467 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   80 / 200 Cost: 0.037437 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   81 / 200 Cost: 0.036446 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   82 / 200 Cost: 0.035491 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   83 / 200 Cost: 0.034568 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   84 / 200 Cost: 0.033677 Predict: ello_whrld_good_morning_see_you_hello_gseat
# Epoch:   85 / 200 Cost: 0.032815 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   86 / 200 Cost: 0.031978 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   87 / 200 Cost: 0.031168 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   88 / 200 Cost: 0.030382 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   89 / 200 Cost: 0.029620 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   90 / 200 Cost: 0.028880 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   91 / 200 Cost: 0.028164 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   92 / 200 Cost: 0.027471 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   93 / 200 Cost: 0.026799 Predict: ello_whrld_good_morning_see_you_hello_great
# Epoch:   94 / 200 Cost: 0.026148 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   95 / 200 Cost: 0.025517 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   96 / 200 Cost: 0.024906 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   97 / 200 Cost: 0.024311 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   98 / 200 Cost: 0.023733 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   99 / 200 Cost: 0.023172 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  100 / 200 Cost: 0.022626 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  101 / 200 Cost: 0.022094 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  102 / 200 Cost: 0.021578 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  103 / 200 Cost: 0.021077 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  104 / 200 Cost: 0.020590 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  105 / 200 Cost: 0.020117 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  106 / 200 Cost: 0.019657 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  107 / 200 Cost: 0.019210 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  108 / 200 Cost: 0.018774 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  109 / 200 Cost: 0.018350 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  110 / 200 Cost: 0.017938 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  111 / 200 Cost: 0.017536 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  112 / 200 Cost: 0.017146 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  113 / 200 Cost: 0.016766 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  114 / 200 Cost: 0.016397 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  115 / 200 Cost: 0.016037 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  116 / 200 Cost: 0.015686 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  117 / 200 Cost: 0.015344 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  118 / 200 Cost: 0.015012 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  119 / 200 Cost: 0.014687 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  120 / 200 Cost: 0.014371 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  121 / 200 Cost: 0.014064 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  122 / 200 Cost: 0.013764 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  123 / 200 Cost: 0.013471 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  124 / 200 Cost: 0.013186 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  125 / 200 Cost: 0.012908 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  126 / 200 Cost: 0.012638 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  127 / 200 Cost: 0.012373 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  128 / 200 Cost: 0.012116 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  129 / 200 Cost: 0.011865 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  130 / 200 Cost: 0.011620 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  131 / 200 Cost: 0.011382 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  132 / 200 Cost: 0.011149 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  133 / 200 Cost: 0.010922 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  134 / 200 Cost: 0.010700 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  135 / 200 Cost: 0.010484 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  136 / 200 Cost: 0.010273 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  137 / 200 Cost: 0.010067 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  138 / 200 Cost: 0.009866 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  139 / 200 Cost: 0.009670 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  140 / 200 Cost: 0.009479 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  141 / 200 Cost: 0.009292 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  142 / 200 Cost: 0.009109 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  143 / 200 Cost: 0.008931 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  144 / 200 Cost: 0.008758 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  145 / 200 Cost: 0.008588 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  146 / 200 Cost: 0.008422 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  147 / 200 Cost: 0.008260 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  148 / 200 Cost: 0.008102 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  149 / 200 Cost: 0.007948 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  150 / 200 Cost: 0.007797 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  151 / 200 Cost: 0.007650 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  152 / 200 Cost: 0.007506 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  153 / 200 Cost: 0.007365 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  154 / 200 Cost: 0.007228 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  155 / 200 Cost: 0.007093 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  156 / 200 Cost: 0.006962 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  157 / 200 Cost: 0.006834 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  158 / 200 Cost: 0.006709 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  159 / 200 Cost: 0.006586 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  160 / 200 Cost: 0.006466 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  161 / 200 Cost: 0.006349 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  162 / 200 Cost: 0.006235 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  163 / 200 Cost: 0.006123 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  164 / 200 Cost: 0.006013 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  165 / 200 Cost: 0.005906 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  166 / 200 Cost: 0.005802 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  167 / 200 Cost: 0.005699 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  168 / 200 Cost: 0.005599 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  169 / 200 Cost: 0.005501 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  170 / 200 Cost: 0.005406 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  171 / 200 Cost: 0.005312 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  172 / 200 Cost: 0.005220 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  173 / 200 Cost: 0.005131 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  174 / 200 Cost: 0.005043 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  175 / 200 Cost: 0.004957 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  176 / 200 Cost: 0.004873 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  177 / 200 Cost: 0.004790 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  178 / 200 Cost: 0.004710 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  179 / 200 Cost: 0.004631 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  180 / 200 Cost: 0.004554 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  181 / 200 Cost: 0.004478 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  182 / 200 Cost: 0.004404 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  183 / 200 Cost: 0.004332 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  184 / 200 Cost: 0.004261 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  185 / 200 Cost: 0.004191 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  186 / 200 Cost: 0.004123 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  187 / 200 Cost: 0.004057 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  188 / 200 Cost: 0.003991 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  189 / 200 Cost: 0.003928 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  190 / 200 Cost: 0.003865 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  191 / 200 Cost: 0.003803 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  192 / 200 Cost: 0.003743 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  193 / 200 Cost: 0.003684 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  194 / 200 Cost: 0.003627 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  195 / 200 Cost: 0.003570 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  196 / 200 Cost: 0.003515 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  197 / 200 Cost: 0.003460 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  198 / 200 Cost: 0.003407 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  199 / 200 Cost: 0.003355 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  200 / 200 Cost: 0.003303 Predict: ello_world_good_morning_see_you_hello_great

# %%
# Probability plot
fig, ax = plt.subplots()
fig.set_size_inches(15,20)
plt.title('Input Sequence', y=1.08, fontsize=20)
plt.xlabel('Probability of Next Character(y) Given Current One(x)', fontsize=25, y=1.5)
plt.ylabel('Character List', fontsize=20)
plot = plt.imshow(pred_act.T, cmap=plt.get_cmap('plasma'))
fig.colorbar(plot, fraction=0.015, pad=0.04)
plt.xticks(np.arange(len(char_data)-1), list(char_raw)[:-1], fontsize=15)
plt.yticks(np.arange(len(char_list)), [idx_to_char[i] for i in range(len(char_list))], fontsize=15)
ax.xaxis.tick_top()

# Annotate
for i, idx in zip(range(len(pred_out)), pred_out):
    annotation = idx_to_char[idx]
    ax.annotate(annotation, xy=(i-0.2, idx+0.2), fontsize=12)

plt.show()

# %% [markdown]
# ### Result:
# - 대략 23번째 Epoch에서부터 이미 첫번째 단어 (hello)를 제외하고 모두 제대로 예측함
# - 67번째 Epoch에 이르러서 모든 연쇄를 정확히 예측함
# - LSTM의 경우보다 예측을 더 빨리 (Epoch 비교시) 잘 해냄 (Cost 비교시)
