# %% [markdown]
# # Simple Character-level Language Model using vanilla RNN
# 2017-04-11 jkang
# Python3.5
# TensorFlow1.0.1
#
# - input:  &nbsp;&nbsp;'hello_world_good_morning_see_you_hello_grea'
# - output: 'ello_world_good_morning_see_you_hello_great'
#
# ### Reference:
# - https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py
# - https://github.com/aymericdamien/TensorFlow-Examples
# - https://hunkim.github.io/ml/
#
# ### Comment:
# - 단어 단위가 아닌 문자 단위로 훈련함
# - 하나의 example만 훈련에 사용함
# - Cell의 종류는 BasicRNNCell을 사용함 (첫번째 Reference 참조)
# - dynamic_rnn방식 사용 (기존 tf.nn.rnn보다 더 시간-계산 효율적이라고 함)
# - AdamOptimizer를 사용

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Input/Ouput data
char_raw = 'hello_world_good_morning_see_you_hello_great'
char_list = list(set(char_raw))
char_to_idx = {c: i for i, c in enumerate(char_list)}
idx_to_char = {i: c for i, c in enumerate(char_list)}
char_data = [char_to_idx[c] for c in char_raw]
char_data_one_hot = tf.one_hot(char_data, depth=len(
    char_list), on_value=1., off_value=0., axis=1, dtype=tf.float32)
char_input = char_data_one_hot[:-1, :]  # 'hello_world_good_morning_see_you_hello_grea'
char_output = char_data_one_hot[1:, :]  # 'ello_world_good_morning_see_you_hello_great'
with tf.Session() as sess:
    char_input = char_input.eval()
    char_output = char_output.eval()

# %%
# Learning parameters
learning_rate = 0.001
max_iter = 200

# Network Parameters
n_input_dim = char_input.shape[1]
n_input_len = char_input.shape[0]
n_output_dim = char_output.shape[1]
n_output_len = char_output.shape[0]
n_hidden = 100

# TensorFlow graph
# (batch_size) x (time_step) x (input_dimension)
x = tf.placeholder(tf.float32, [1, None, n_input_dim])
# (batch_size) x (time_step) x (output_dimension)
y = tf.placeholder(tf.float32, [1, None, n_output_dim])

# Parameters
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_output_dim], seed=1))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_output_dim], seed=1))
}

# RNN-cell
def RNN(inputs, weights, biases):
    # Reshape to (time_step) x (batch_size) x (input_dimension)
    inputs = tf.transpose(inputs, [1, 0, 2])
    # Reshape to (time_step)*(batch_size) x (input_dimension)
    inputs = tf.reshape(inputs, [-1, n_input_dim])
    # Split to get a list of time_step tensors of shape (batch_size, input_dimension)
    # final 'inputs' is a list of n_input_len elements
    # (=number of frames)
    inputs = tf.split(value=inputs, num_or_size_splits=n_input_len, axis=0)

    rnn = tf.contrib.rnn.BasicRNNCell(n_hidden)
    outputs, states = tf.nn.dynamic_rnn(rnn, x, dtype=tf.float32)
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

def softmax(x):
    rowmax = np.max(x, axis=1)
    x -= rowmax.reshape((x.shape[0] ,1)) # for numerical stability
    x = np.exp(x)
    sum_x = np.sum(x, axis=1).reshape((x.shape[0],1))
    return x / sum_x

pred = RNN(x, weights, biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Learning
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_x = char_input.reshape((1, char_input.shape[0], n_input_dim))
    train_y = char_output.reshape((1, char_output.shape[0], n_output_dim))
    for i in range(max_iter):
        _, loss, p = sess.run([optimizer, cost, pred],
                              feed_dict={x: train_x, y: train_y})
        if i is max_iter-1:
            pred_act = softmax(p)
        pred_out = np.argmax(p, axis=1)
        print('Epoch: {:>4}'.format(i + 1), '/', str(max_iter),
              'Cost: {:4f}'.format(loss), 'Predict:', ''.join([idx_to_char[i] for i in pred_out]))
# Out:
# Epoch:    1 / 200 Cost: 4.770187 Predict: _nmlslnhlridrnhmlrarrlslalnrsaa__gorlhlrhar
# Epoch:    2 / 200 Cost: 3.942535 Predict: _nmlslnhlaiirnlmlganrlol_lnlydm__gnrlslrear
# Epoch:    3 / 200 Cost: 3.318490 Predict: _nmlslnhlaidonlmlganmlol_lnlydm__nnlldlreao
# Epoch:    4 / 200 Cost: 2.786463 Predict: _nmaslnhlaidonlmlg_nmlol_l_lydm__nnlldlreao
# Epoch:    5 / 200 Cost: 2.349388 Predict: _nlaslnhla_donlmgglndlol_d_lydm__nnlodgreay
# Epoch:    6 / 200 Cost: 1.994180 Predict: _nla_enelo_gonlmgglndlol_d_l_dm__nnlodgreay
# Epoch:    7 / 200 Cost: 1.699094 Predict: _nlo_enrlo_goo_ggolndlolld___om__n_lodgoeay
# Epoch:    8 / 200 Cost: 1.449186 Predict: _nlo_enrlo_goo_ggorniiolyd___om__nllo_goeay
# Epoch:    9 / 200 Cost: 1.235422 Predict: _nlo_enrlo_gooaggorniiolyd___om_enllo_goeat
# Epoch:   10 / 200 Cost: 1.051323 Predict: _nlo_enrlo_gooaggorniig_yd___on_enllo_goeat
# Epoch:   11 / 200 Cost: 0.891003 Predict: _nlo_eorld_gooaigorniig_see__ou_enllo_goeat
# Epoch:   12 / 200 Cost: 0.749841 Predict: _nlo_gorld_gooaigorni_g_see_you_hello_goeat
# Epoch:   13 / 200 Cost: 0.626190 Predict: _nlo_gorld_gooa_gorni_g_see_you_hello_goeat
# Epoch:   14 / 200 Cost: 0.520619 Predict: _elo_gorld_good_gorning_see_you_hello_goeat
# Epoch:   15 / 200 Cost: 0.433598 Predict: _elo_gorld_good_morning_see_you_hello_great
# Epoch:   16 / 200 Cost: 0.363917 Predict: _elo_world_good_morning_see_you_hello_great
# Epoch:   17 / 200 Cost: 0.308590 Predict: _elo_world_good_morning_see_you_hello_great
# Epoch:   18 / 200 Cost: 0.264344 Predict: _elo_world_good_morning_see_you_hello_great
# Epoch:   19 / 200 Cost: 0.228916 Predict: _elo_world_good_morning_see_you_hello_great
# Epoch:   20 / 200 Cost: 0.200753 Predict: _elo_world_good_morning_see_you_hello_great
# Epoch:   21 / 200 Cost: 0.178255 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   22 / 200 Cost: 0.159847 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   23 / 200 Cost: 0.144424 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   24 / 200 Cost: 0.131342 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   25 / 200 Cost: 0.120171 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   26 / 200 Cost: 0.110583 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   27 / 200 Cost: 0.102327 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   28 / 200 Cost: 0.095192 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   29 / 200 Cost: 0.088989 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   30 / 200 Cost: 0.083548 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   31 / 200 Cost: 0.078722 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   32 / 200 Cost: 0.074398 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   33 / 200 Cost: 0.070487 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   34 / 200 Cost: 0.066926 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   35 / 200 Cost: 0.063669 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   36 / 200 Cost: 0.060679 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   37 / 200 Cost: 0.057928 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   38 / 200 Cost: 0.055389 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   39 / 200 Cost: 0.053040 Predict: _llo_world_good_morning_see_you_hello_great
# Epoch:   40 / 200 Cost: 0.050860 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   41 / 200 Cost: 0.048828 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   42 / 200 Cost: 0.046927 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   43 / 200 Cost: 0.045142 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   44 / 200 Cost: 0.043461 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   45 / 200 Cost: 0.041871 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   46 / 200 Cost: 0.040364 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   47 / 200 Cost: 0.038932 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   48 / 200 Cost: 0.037569 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:   49 / 200 Cost: 0.036270 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:
Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  142 / 200 Cost: 0.005566 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  143 / 200 Cost: 0.005506 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  144 / 200 Cost: 0.005447 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  145 / 200 Cost: 0.005389 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  146 / 200 Cost: 0.005332 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  147 / 200 Cost: 0.005277 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  148 / 200 Cost: 0.005222 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  149 / 200 Cost: 0.005168 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  150 / 200 Cost: 0.005116 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  151 / 200 Cost: 0.005064 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  152 / 200 Cost: 0.005013 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  153 / 200 Cost: 0.004963 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  154 / 200 Cost: 0.004913 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  155 / 200 Cost: 0.004865 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  156 / 200 Cost: 0.004817 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  157 / 200 Cost: 0.004770 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  158 / 200 Cost: 0.004724 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  159 / 200 Cost: 0.004679 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  160 / 200 Cost: 0.004634 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  161 / 200 Cost: 0.004590 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  162 / 200 Cost: 0.004547 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  163 / 200 Cost: 0.004505 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  164 / 200 Cost: 0.004463 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  165 / 200 Cost: 0.004422 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  166 / 200 Cost: 0.004381 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  167 / 200 Cost: 0.004341 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  168 / 200 Cost: 0.004302 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  169 / 200 Cost: 0.004263 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  170 / 200 Cost: 0.004225 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  171 / 200 Cost: 0.004187 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  172 / 200 Cost: 0.004150 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  173 / 200 Cost: 0.004114 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  174 / 200 Cost: 0.004078 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  175 / 200 Cost: 0.004042 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  176 / 200 Cost: 0.004007 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  177 / 200 Cost: 0.003973 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  178 / 200 Cost: 0.003939 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  179 / 200 Cost: 0.003906 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  180 / 200 Cost: 0.003873 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  181 / 200 Cost: 0.003840 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  182 / 200 Cost: 0.003808 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  183 / 200 Cost: 0.003776 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  184 / 200 Cost: 0.003745 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  185 / 200 Cost: 0.003714 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  186 / 200 Cost: 0.003684 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  187 / 200 Cost: 0.003654 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  188 / 200 Cost: 0.003624 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  189 / 200 Cost: 0.003595 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  190 / 200 Cost: 0.003566 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  191 / 200 Cost: 0.003538 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  192 / 200 Cost: 0.003510 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  193 / 200 Cost: 0.003482 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  194 / 200 Cost: 0.003455 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  195 / 200 Cost: 0.003428 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  196 / 200 Cost: 0.003401 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  197 / 200 Cost: 0.003375 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  198 / 200 Cost: 0.003349 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  199 / 200 Cost: 0.003324 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  200 / 200 Cost: 0.003298 Predict: ello_world_good_morning_see_you_hello_great

# %%
# Probability plot
fig, ax = plt.subplots()
fig.set_size_inches(15,20)
plt.title('Input Sequence', y=1.08, fontsize=20)
plt.xlabel('Probability of Next Character(y) Given Current One(x)', fontsize=25, y=1.5)
plt.ylabel('Character List', fontsize=20)
plot = plt.imshow(pred_act.T, cmap=plt.get_cmap('plasma'))
fig.colorbar(plot, fraction=0.015, pad=0.04)
plt.xticks(np.arange(len(char_data)-1), list(char_raw)[:-1], fontsize=15)
plt.yticks(np.arange(len(char_list)), [idx_to_char[i] for i in range(len(char_list))], fontsize=15)
ax.xaxis.tick_top()

# Annotate
for i, idx in zip(range(len(pred_out)), pred_out):
    annotation = idx_to_char[idx]
    ax.annotate(annotation, xy=(i-0.2, idx+0.2), fontsize=12)

plt.show()

# %% [markdown]
# ### Result:
# - 대략 23번째 Epoch에서부터 이미 첫번째 단어 (hello)를 제외하고 모두 제대로 예측함
# - 67번째 Epoch에 이르러서 모든 연쇄를 정확히 예측함
# - LSTM의 경우보다 예측을 더 빨리 (Epoch 비교시) 잘 해냄 (Cost 비교시)
