# %% [markdown]
# # Simple Character-level Language Model using vanilla RNN
# 2017-04-11 jkang
# Python3.5
# TensorFlow1.0.1
#
# - input:  &nbsp;&nbsp;'hello_world_good_morning_see_you_hello_grea'
# - output: 'ello_world_good_morning_see_you_hello_great'
#
# ### Reference:
# - https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py
# - https://github.com/aymericdamien/TensorFlow-Examples
# - https://hunkim.github.io/ml/
#
# ### Comment:
# - 단어 단위가 아닌 문자 단위로 훈련함
# - 하나의 example만 훈련에 사용함
# - Cell의 종류는 BasicRNNCell을 사용함 (첫번째 Reference 참조)
# - dynamic_rnn방식 사용 (기존 tf.nn.rnn보다 더 시간-계산 효율적이라고 함)
# - AdamOptimizer를 사용

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Input/Ouput data
char_raw = 'hello_world_good_morning_see_you_hello_great'
char_list = list(set(char_raw))
char_to_idx = {c: i for i, c in enumerate(char_list)}
idx_to_char = {i: c for i, c in enumerate(char_list)}
char_data = [char_to_idx[c] for c in char_raw]
char_data_one_hot = tf.one_hot(char_data, depth=len(
    char_list), on_value=1., off_value=0., axis=1, dtype=tf.float32)
char_input = char_data_one_hot[:-1, :]  # 'hello_world_good_morning_see_you_hello_grea'
char_output = char_data_one_hot[1:, :]  # 'ello_world_good_morning_see_you_hello_great'
with tf.Session() as sess:
    char_input = char_input.eval()
    char_output = char_output.eval()

# %%
# Learning parameters
learning_rate = 0.001
max_iter = 200

# Network Parameters
n_input_dim = char_input.shape[1]
n_input_len = char_input.shape[0]
n_output_dim = char_output.shape[1]
n_output_len = char_output.shape[0]
n_hidden = 100

# TensorFlow graph
# (batch_size) x (time_step) x (input_dimension)
x = tf.placeholder(tf.float32, [1, None, n_input_dim])
# (batch_size) x (time_step) x (output_dimension)
y = tf.placeholder(tf.float32, [1, None, n_output_dim])

# Parameters
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_output_dim], seed=1))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_output_dim], seed=1))
}

# RNN-cell
def RNN(x, weights, biases):
    rnn = tf.contrib.rnn.BasicRNNCell(n_hidden)
    outputs, states = tf.nn.dynamic_rnn(rnn, x, dtype=tf.float32)
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

def softmax(x):
    rowmax = np.max(x, axis=1)
    x -= rowmax.reshape((x.shape[0] ,1)) # for numerical stability
    x = np.exp(x)
    sum_x = np.sum(x, axis=1).reshape((x.shape[0],1))
    return x / sum_x

pred = RNN(x, weights, biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Learning
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_x = char_input.reshape((1, char_input.shape[0], n_input_dim))
    train_y = char_output.reshape((1, char_output.shape[0], n_output_dim))
    for i in range(max_iter):
        _, loss, p = sess.run([optimizer, cost, pred],
                              feed_dict={x: train_x, y: train_y})
        if i is max_iter-1:
            pred_act = softmax(p)
        pred_out = np.argmax(p, axis=1)
        print('Epoch: {:>4}'.format(i + 1), '/', str(max_iter),
              'Cost: {:4f}'.format(loss), 'Predict:', ''.join([idx_to_char[i] for i in pred_out]))
# Out:
# Epoch:    1 / 200 Cost: 5.466847 Predict: uyyimusulauuuullguyyiusuuuyusumueumuiudumui
# Epoch:    2 / 200 Cost: 4.800925 Predict: uyyimusulyuusoylguyyiosmyoyisyyoeumyiolsoyy
# Epoch:    3 / 200 Cost: 4.265936 Predict: uyymmdsudy_esoylguyyiosmyhyysyymemmyimlsoyy
# Epoch:    4 / 200 Cost: 3.739779 Predict: uyymmlsudy_dsoylguyyiosyyhyysyymemyyimlsnyy
# Epoch:    5 / 200 Cost: 3.274163 Predict: uyymmlsuga_dsoylmuyyimsyyhyysohmemyiimlseyy
# Epoch:    6 / 200 Cost: 2.867745 Predict: uyym_lsuga_dmoylmutuimsyyhyyyoumemuiimlmeyy
# Epoch:    7 / 200 Cost: 2.508031 Predict: uyym_lslgd_dmoylmatui_syyhyyyoumemuii_gmeyy
# Epoch:    8 / 200 Cost: 2.185637 Predict: uylm_lslgd_gmoylmatui_gyyhyyyou_ehlim_gmeyy
# Epoch:    9 / 200 Cost: 1.895510 Predict: uylm_lslgd_gmoylmatnidgyyhy_you_hhllm_goeym
# Epoch:   10 / 200 Cost: 1.635855 Predict: uylo_lllgd_goodlmatnidg_she_you_hhllm_goeam
# Epoch:   11 / 200 Cost: 1.407717 Predict: uylo_lllgd_gooddmatnidg_she_you_hhllo_goeam
# Epoch:   12 / 200 Cost: 1.212286 Predict: uylo_wrlld_gooddmatnidg_sye_you_hhllo_gream
# Epoch:   13 / 200 Cost: 1.043020 Predict: uylo_wrlld_gooddmalniwg_see_you_hhllo_gream
# Epoch:   14 / 200 Cost: 0.887753 Predict: uylo_wrlld_good_mulniwg_see_you_hello_gream
# Epoch:   15 / 200 Cost: 0.747249 Predict: uylo_wrlld_good_molniwg_see_you_hello_gream
# Epoch:   16 / 200 Cost: 0.629872 Predict: uylo_wrlld_good_morning_see_you_hello_great
# Epoch:   17 / 200 Cost: 0.535013 Predict: uylo_wrrld_good_morning_see_you_hello_great
# Epoch:   18 / 200 Cost: 0.458479 Predict: uylo_wrrld_good_morning_see_you_hello_great
# Epoch:   19 / 200 Cost: 0.397419 Predict: uylo_wrrld_good_morning_see_you_hello_great
# Epoch:   20 / 200 Cost: 0.349119 Predict: uylo_wrrld_good_morning_see_you_hello_great
# Epoch:   21 / 200 Cost: 0.310537 Predict: uylo_wrrld_good_morning_see_you_hello_great
# Epoch:   22 / 200 Cost: 0.278845 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   23 / 200 Cost: 0.251971 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   24 / 200 Cost: 0.228816 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   25 / 200 Cost: 0.209048 Predict: uylo_world_good_morning_see_you_hello_great
# Epoch:   26 / 200 Cost: 0.192479 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   27 / 200 Cost: 0.178562 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   28 / 200 Cost: 0.166488 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   29 / 200 Cost: 0.155679 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   30 / 200 Cost: 0.145985 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   31 / 200 Cost: 0.137433 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   32 / 200 Cost: 0.129969 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   33 / 200 Cost: 0.123436 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   34 / 200 Cost: 0.117653 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   35 / 200 Cost: 0.112467 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   36 / 200 Cost: 0.107774 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   37 / 200 Cost: 0.103505 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   38 / 200 Cost: 0.099612 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   39 / 200 Cost: 0.096050 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   40 / 200 Cost: 0.092770 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   41 / 200 Cost: 0.089726 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   42 / 200 Cost: 0.086873 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   43 / 200 Cost: 0.084175 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   44 / 200 Cost: 0.081607 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   45 / 200 Cost: 0.079153 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   46 / 200 Cost: 0.076800 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   47 / 200 Cost: 0.074539 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   48 / 200 Cost: 0.072362 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   49 / 200 Cost: 0.070260 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   50 / 200 Cost: 0.068223 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:   51 / 200 Cost: 0.066243 Predict: ullo_world_good_morning_see_you_hello_great
# Epoch:
Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  141 / 200 Cost: 0.006714 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  142 / 200 Cost: 0.006628 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  143 / 200 Cost: 0.006545 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  144 / 200 Cost: 0.006463 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  145 / 200 Cost: 0.006384 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  146 / 200 Cost: 0.006306 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  147 / 200 Cost: 0.006230 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  148 / 200 Cost: 0.006155 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  149 / 200 Cost: 0.006082 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  150 / 200 Cost: 0.006011 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  151 / 200 Cost: 0.005942 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  152 / 200 Cost: 0.005873 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  153 / 200 Cost: 0.005807 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  154 / 200 Cost: 0.005741 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  155 / 200 Cost: 0.005677 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  156 / 200 Cost: 0.005614 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  157 / 200 Cost: 0.005553 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  158 / 200 Cost: 0.005493 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  159 / 200 Cost: 0.005433 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  160 / 200 Cost: 0.005375 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  161 / 200 Cost: 0.005319 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  162 / 200 Cost: 0.005263 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  163 / 200 Cost: 0.005208 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  164 / 200 Cost: 0.005154 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  165 / 200 Cost: 0.005101 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  166 / 200 Cost: 0.005050 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  167 / 200 Cost: 0.004999 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  168 / 200 Cost: 0.004949 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  169 / 200 Cost: 0.004900 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  170 / 200 Cost: 0.004851 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  171 / 200 Cost: 0.004804 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  172 / 200 Cost: 0.004757 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  173 / 200 Cost: 0.004711 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  174 / 200 Cost: 0.004666 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  175 / 200 Cost: 0.004622 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  176 / 200 Cost: 0.004579 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  177 / 200 Cost: 0.004536 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  178 / 200 Cost: 0.004493 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  179 / 200 Cost: 0.004452 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  180 / 200 Cost: 0.004411 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  181 / 200 Cost: 0.004371 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  182 / 200 Cost: 0.004331 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  183 / 200 Cost: 0.004293 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  184 / 200 Cost: 0.004254 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  185 / 200 Cost: 0.004216 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  186 / 200 Cost: 0.004179 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  187 / 200 Cost: 0.004143 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  188 / 200 Cost: 0.004107 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  189 / 200 Cost: 0.004071 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  190 / 200 Cost: 0.004036 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  191 / 200 Cost: 0.004002 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  192 / 200 Cost: 0.003968 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  193 / 200 Cost: 0.003934 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  194 / 200 Cost: 0.003901 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  195 / 200 Cost: 0.003869 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  196 / 200 Cost: 0.003837 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  197 / 200 Cost: 0.003805 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  198 / 200 Cost: 0.003774 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  199 / 200 Cost: 0.003743 Predict: ello_world_good_morning_see_you_hello_great
# Epoch:  200 / 200 Cost: 0.003713 Predict: ello_world_good_morning_see_you_hello_great

# %%
# Probability plot
fig, ax = plt.subplots()
fig.set_size_inches(15,20)
plt.title('Input Sequence', y=1.08, fontsize=20)
plt.xlabel('Probability of Next Character(y) Given Current One(x)', fontsize=25, y=1.5)
plt.ylabel('Character List', fontsize=20)
plot = plt.imshow(pred_act.T, cmap=plt.get_cmap('plasma'))
fig.colorbar(plot, fraction=0.015, pad=0.04)
plt.xticks(np.arange(len(char_data)-1), list(char_raw)[:-1], fontsize=15)
plt.yticks(np.arange(len(char_list)), [idx_to_char[i] for i in range(len(char_list))], fontsize=15)
ax.xaxis.tick_top()

# Annotate
for i, idx in zip(range(len(pred_out)), pred_out):
    annotation = idx_to_char[idx]
    ax.annotate(annotation, xy=(i-0.2, idx+0.2), fontsize=12)

plt.show()

# %% [markdown]
# ### Result:
# - 대략 23번째 Epoch에서부터 이미 첫번째 단어 (hello)를 제외하고 모두 제대로 예측함
# - 67번째 Epoch에 이르러서 모든 연쇄를 정확히 예측함
# - LSTM의 경우보다 예측을 더 빨리 (Epoch 비교시) 잘 해냄 (Cost 비교시)
