# %% [markdown]
# # Simple Character-level Language Model using LSTM
# 2017-04-11 jkang
# Python3.5
# TensorFlow1.0.1
#
# - input:  &nbsp;&nbsp;'hello_world_good_morning_see_you_hello_grea'
# - output: 'ello_world_good_morning_see_you_hello_great'
#
# ### Reference:
# - https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py
# - https://github.com/aymericdamien/TensorFlow-Examples
# - https://hunkim.github.io/ml/
#
# ### Comment:
# - 단어 단위가 아닌 문자 단위로 훈련함
# - 하나의 example만 훈련에 사용함
# - Cell의 종류는 BasicLSTMCell을 사용함 (첫번째 Reference 참조)
# - dynamic_rnn방식 사용 (기존 tf.nn.rnn보다 더 시간-계산 효율적이라고 함)
# - AdamOptimizer를 사용

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Input/Ouput data
char_raw = 'hello_world_good_morning_see_you_hello_great'
char_list = list(set(char_raw))
char_to_idx = {c: i for i, c in enumerate(char_list)}
idx_to_char = {i: c for i, c in enumerate(char_list)}
char_data = [char_to_idx[c] for c in char_raw]
char_data_one_hot = tf.one_hot(char_data, depth=len(
    char_list), on_value=1., off_value=0., axis=1, dtype=tf.float32)
char_input = char_data_one_hot[:-1, :]  # 'hello_world_good_morning_see_you_hello_grea'
char_output = char_data_one_hot[1:, :]  # 'ello_world_good_morning_see_you_hello_great'
with tf.Session() as sess:
    char_input = char_input.eval()
    char_output = char_output.eval()

# %%
# Learning parameters
learning_rate = 0.001
max_iter = 200

# Network Parameters
n_input_dim = char_input.shape[1]
n_input_len = char_input.shape[0]
n_output_dim = char_output.shape[1]
n_output_len = char_output.shape[0]
n_hidden = 100

# TensorFlow graph
# (batch_size) x (time_step) x (input_dimension)
x = tf.placeholder(tf.float32, [1, None, n_input_dim])
# (batch_size) x (time_step) x (output_dimension)
y = tf.placeholder(tf.float32, [1, None, n_output_dim])

# Parameters
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_output_dim], seed=1))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_output_dim], seed=1))
}

# RNN-LSTM cell
def RNN(inputs, weights, biases):
    # Reshape to (time_step) x (batch_size) x (input_dimension)
    inputs = tf.transpose(inputs, [1, 0, 2])
    # Reshape to (time_step)*(batch_size) x (input_dimension)
    inputs = tf.reshape(inputs, [-1, n_input_dim])
    # Split to get a list of time_step tensors of shape (batch_size, input_dimension)
    # final 'inputs' is a list of n_input_len elements
    # (=number of frames)
    inputs = tf.split(value=inputs, num_or_size_splits=n_input_len, axis=0)

    lstm = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    outputs, states = tf.nn.dynamic_rnn(lstm, x, dtype=tf.float32)
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

def softmax(x):
    rowmax = np.max(x, axis=1)
    x -= rowmax.reshape((x.shape[0] ,1)) # for numerical stability
    x = np.exp(x)
    sum_x = np.sum(x, axis=1).reshape((x.shape[0],1))
    return x / sum_x

pred = RNN(x, weights, biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Learning
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_x = char_input.reshape((1, char_input.shape[0], n_input_dim))
    train_y = char_output.reshape((1, char_output.shape[0], n_output_dim))
    for i in range(max_iter):
        _, loss, p = sess.run([optimizer, cost, pred],
                              feed_dict={x: train_x, y: train_y})
        if i is max_iter-1:
            pred_act = softmax(p)
        pred_out = np.argmax(p, axis=1)
        print('Epoch: {:>4}'.format(i + 1), '/', str(max_iter),
              'Cost: {:4f}'.format(loss), 'Predict:', ''.join([idx_to_char[i] for i in pred_out]))
# Out:
# Epoch:    1 / 200 Cost: 3.842885 Predict: iiiiiiiiiiiiiiiiiiiiiimiiiiiiiiiiiiiiitiiii
# Epoch:    2 / 200 Cost: 3.733372 Predict: iiiiiiiiiiiiiiiiiiiiiimiiiiiiiiittiiiitiiii
# Epoch:    3 / 200 Cost: 3.629220 Predict: iiiiitiiititiiiiiiiiimmimiiiiiiittittttitii
# Epoch:    4 / 200 Cost: 3.526526 Predict: iiiiittittitiiiiiiiimmmimiiiiiiittittttttti
# Epoch:    5 / 200 Cost: 3.422292 Predict: iiiiittittitiiiiimiimgggmmiismittthtttttttt
# Epoch:    6 / 200 Cost: 3.314143 Predict: iiiiitttttittttitmitmgggmmggsmtttuhhgtttttt
# Epoch:    7 / 200 Cost: 3.200549 Predict: iiiiittttttttttitmmtmgggggggshhuuuuuggttttt
# Epoch:    8 / 200 Cost: 3.082167 Predict: iiiiittttttttttitmmt_g_g__gguuguuuuuggtttgg
# Epoch:    9 / 200 Cost: 2.965826 Predict: iiiiitttttttttt__m_______________uuug______
# Epoch:   10 / 200 Cost: 2.872566 Predict: iiiiittttt__t______________________________
# Epoch:   11 / 200 Cost: 2.821098 Predict: iiiiitttto_________________________________
# Epoch:   12 / 200 Cost: 2.760385 Predict: iiiiitttoo_________________________________
# Epoch:   13 / 200 Cost: 2.676201 Predict: iiiggttooo_oo______________________________
# Epoch:   14 / 200 Cost: 2.609863 Predict: iiiggttoooooooo_o_o__n_______e__oeeoooooooo
# Epoch:   15 / 200 Cost: 2.575337 Predict: iiiggttooooooooooooo____eeeeeeeoeeelloooeoo
# Epoch:   16 / 200 Cost: 2.555634 Predict: iiiggttooooooooooooo_e_eeeeeeeeeeeellgogeeo
# Epoch:   17 / 200 Cost: 2.534673 Predict: iiiggtoooooooooooooo_eeeeeeeeeeeeeellgogeeo
# Epoch:   18 / 200 Cost: 2.508274 Predict: iiiggooooooooooooooo_eeeeeeeeeeeeeellgogeeo
# Epoch:   19 / 200 Cost: 2.478550 Predict: iiiggooooooooooooooo_eeeeeeeeeeeeeellgogeoo
# Epoch:   20 / 200 Cost: 2.447930 Predict: iiiggooooooooooooooo_e_eeeeeeeeeeeelloooeoo
# Epoch:   21 / 200 Cost: 2.417572 Predict: iiiggoooooooooo_oooo_e__eeeeeee_eeelloooooo
# Epoch:   22 / 200 Cost: 2.387777 Predict: iiiggoooooooooo_ooo__e__eeeeee__eeell_o__oo
# Epoch:   23 / 200 Cost: 2.358172 Predict: iiigooooooooooo_o_______eeeeee__eeell_____o
# Epoch:   24 / 200 Cost: 2.327474 Predict: iiigooooooooooo_o_______eeeeee___ee________
# Epoch:   25 / 200 Cost: 2.294104 Predict: iiigooooooooooo_oo______eee_ee___ee________
# Epoch:   26 / 200 Cost: 2.258002 Predict: iiigooooooooooo_oo______eee_ee___eel_______
# Epoch:   27 / 200 Cost: 2.221465 Predict: iiioooooooooooo_ooo__n__eeeeee__eeell______
# Epoch:   28 / 200 Cost: 2.187461 Predict: iiioooooooooooooooon_n__eeeeee__eeell_____o
# Epoch:   29 / 200 Cost: 2.156882 Predict: iiiooooooooooooooonnnnn_eeeeee__eeell_l_e_o
# Epoch:   30 / 200 Cost: 2.127212 Predict: iiiooooooooooooooonnnnn_eeeeee__eelll_llelo
# Epoch:   31 / 200 Cost: 2.094277 Predict: iiiooooooooooooooonnnnnneeeeee__eellllllelo
# Epoch:   32 / 200 Cost: 2.055848 Predict: iiiooooooooooooooonnnnn_eeeeee__eellllllelt
# Epoch:   33 / 200 Cost: 2.013193 Predict: iiiooooooooooooooonnnnn_eeeeee__eellllllgat
# Epoch:   34 / 200 Cost: 1.969566 Predict: iilooooooooooooooonnnnn_eee_ee__eelllllgaat
# Epoch:   35 / 200 Cost: 1.927894 Predict: iilooooooooooodooonnnn___ee_ee__eelllllaaat
# Epoch:   36 / 200 Cost: 1.889278 Predict: iiloooooooooood_oonnnn___ee_ee__eeell_laaat
# Epoch:   37 / 200 Cost: 1.852266 Predict: iiloooooooooodd_ooon_n___ee__e__eeell_orttt
# Epoch:   38 / 200 Cost: 1.813435 Predict: iiloooooooooodddooon_n___e______eeell_orttt
# Epoch:   39 / 200 Cost: 1.771356 Predict: iiloooooooooodddooon_n___e______eeell_rrett
# Epoch:   40 / 200 Cost: 1.728838 Predict: iiloooooooooodddooonnn___e______eeellorreat
# Epoch:   41 / 200 Cost: 1.687294 Predict: iiloooooooooodddoonnnn__see_____eelllorrert
# Epoch:   42 / 200 Cost: 1.643718 Predict: iiloooooooooodddoonnnnn_see_____helllorreat
# Epoch:   43 / 200 Cost: 1.596691 Predict: iiloooooooooodddoonnnnn_see_____helllorreat
# Epoch:   44 / 200 Cost: 1.550750 Predict: iiloooooooooood_oonnnnn_see_____helllogreat
# Epoch:   45 / 200 Cost: 1.510037 Predict: iilooooooo_oood_oonnnnn_eee______elll_great
# Epoch:   46 / 200 Cost: 1.471395 Predict: iilooooooo_oood_oonnnnn_eee______elll_great
# Epoch:   47 / 200 Cost: 1.429041 Predict: iilooooooo_oood_oonnnnn_eee______elll_great
# Epoch:   48 / 200 Cost: 1.385510 Predict: iilloooooo_oood_oornnnn_eee__o__helll_great
# Epoch:   49 / 200 Cost: 1.346456 Predict: illloooooo_oood_oornnnn_eeeeyou_helll_great
# Epoch:   50 / 200 Cost: 1.311073 Predict: illl_ooooo_oood_oorning_eeeyyou_helll_great
# Epoch:   51 / 200 Cost: 1.275921 Predict: illl_ooooo_oood_oorning_seeyyo__helll_great
# Epoch:   52 / 200 Cost: 1.239110 Predict: illl_ooooo_oood_oornnnn_see_yo__helll_great
# Epoch:   53 / 200 Cost: 1.203098 Predict: illl_ooooo_oood_oornnnn_see_yo__hllll_great
# Epoch:   54 / 200 Cost: 1.172569 Predict: illl_ooooo_oood_oornnnn_see__o__hello_great
# Epoch:   55 / 200 Cost: 1.142052 Predict: illl_ooooo_oood_oornnng_see_you_helll_great
# Epoch:   56 / 200 Cost: 1.111166 Predict: illl_ooooo_oood_oorning_see__o__hello_great
# Epoch:   57 / 200 Cost: 1.087501 Predict: illl_ooodd_oood_morning_seeyyuu_helll_great
# Epoch:   58 / 200 Cost: 1.058846 Predict: illl_ooold_oood_morning_see_you_hello_great
# Epoch:   59 / 200 Cost: 1.060131 Predict: illl_ooold_oood_morning_seeyyuu_hello_grett
# Epoch:   60 / 200 Cost: 1.041190 Predict: illl_ooold_oood_oornnng__ee_you_helll_great
# Epoch:   61 / 200 Cost: 0.983561 Predict: illl_ooold_oood_mornnng_eee_you_hello_great
# Epoch:   62 / 200 Cost: 0.970991 Predict: illl_ooold_oood_morning_see_you_hlllo_great
# Epoch:   63 / 200 Cost: 0.948457 Predict: illl_ooold_oood_morning_see_you_helll_great
# Epoch:   64 / 200 Cost: 0.914702 Predict: illl_ooold_oood_morning_see_you_hello_great
# Epoch:   65 / 200 Cost: 0.907510 Predict: illl_oorld_oood_morning_see_you_hello_great
# Epoch:   66 / 200 Cost: 0.871553 Predict: illl_oorld_oood_morning_see_you_hello_great
# Epoch:   67 / 200 Cost: 0.862840 Predict: illl_oorld_oood_morning_see_you_helll_great
# Epoch:   68 / 200 Cost: 0.836661 Predict: illl_oorld_oood_mornnng_eee_you_hello_great
# Epoch:   69 / 200 Cost: 0.814965 Predict: illl_oorld_oood_mornnng_see_you_hello_great
# Epoch:   70 / 200 Cost: 0.802283 Predict: illo_oorld_dood_morning_see_you_hello_great
# Epoch:   71 / 200 Cost: 0.774390 Predict: illo_oorld_dood_morning_see_you_hello_great
# Epoch:   72 / 200 Cost: 0.767394 Predict: illo_world_good_mornnng_see_you_hello_great
# Epoch:   73 / 200 Cost: 0.738858 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   74 / 200 Cost: 0.731387 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   75 / 200 Cost: 0.711245 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   76 / 200 Cost: 0.691661 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   77 / 200 Cost: 0.683712 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   78 / 200 Cost: 0.667392 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   79 / 200 Cost: 0.644891 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   80 / 200 Cost: 0.641572 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   81 / 200 Cost: 0.626190 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   82 / 200 Cost: 0.603568 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   83 / 200 Cost: 0.594701 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   84 / 200 Cost: 0.593049 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   85 / 200 Cost: 0.564706 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   86 / 200 Cost: 0.555376 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   87 / 200 Cost: 0.546523 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   88 / 200 Cost: 0.533163 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   89 / 200 Cost: 0.526432 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   90 / 200 Cost: 0.511553 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   91 / 200 Cost: 0.494673 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   92 / 200 Cost: 0.490660 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   93 / 200 Cost: 0.474637 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   94 / 200 Cost: 0.467122 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   95 / 200 Cost: 0.458930 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   96 / 200 Cost: 0.450191 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   97 / 200 Cost: 0.456517 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   98 / 200 Cost: 0.472971 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:   99 / 200 Cost: 0.520819 Predict: illo_world_good_morning_see__ou_helll_great
# Epoch:  100 / 200 Cost: 0.550797 Predict: illo_world_good_morning_seeyyou_heloo_graat
# Epoch:  101 / 200 Cost: 0.431123 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  102 / 200 Cost: 0.492259 Predict: illo_world_good_morning_see__ou_helll_great
# Epoch:  103 / 200 Cost: 0.426460 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  104 / 200 Cost: 0.449488 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  105 / 200 Cost: 0.407128 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  106 / 200 Cost: 0.426997 Predict: illo_world_good_morning_see_you_helll_great
# Epoch:  107 / 200 Cost: 0.395671 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  108 / 200 Cost: 0.396214 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  109 / 200 Cost: 0.390734 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  110 / 200 Cost: 0.378864 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  111 / 200 Cost: 0.361509 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  112 / 200 Cost: 0.373391 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  113 / 200 Cost: 0.356184 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  114 / 200 Cost: 0.341364 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  115 / 200 Cost: 0.350428 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  116 / 200 Cost: 0.339870 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  117 / 200 Cost: 0.325523 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  118 / 200 Cost: 0.327514 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  119 / 200 Cost: 0.325344 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  120 / 200 Cost: 0.313842 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  121 / 200 Cost: 0.308328 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  122 / 200 Cost: 0.308508 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  123 / 200 Cost: 0.303236 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  124 / 200 Cost: 0.294588 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  125 / 200 Cost: 0.291784 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  126 / 200 Cost: 0.289774 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  127 / 200 Cost: 0.284015 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  128 / 200 Cost: 0.278867 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  129 / 200 Cost: 0.275457 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  130 / 200 Cost: 0.272431 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  131 / 200 Cost: 0.268156 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  132 / 200 Cost: 0.263307 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  133 / 200 Cost: 0.260348 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  134 / 200 Cost: 0.257252 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  135 / 200 Cost: 0.253033 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  136 / 200 Cost: 0.249428 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  137 / 200 Cost: 0.246305 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  138 / 200 Cost: 0.243141 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  139 / 200 Cost: 0.239641 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  140 / 200 Cost: 0.236298 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  141 / 200 Cost: 0.233534 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  142 / 200 Cost: 0.230342 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  143 / 200 Cost: 0.227190 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  144 / 200 Cost: 0.224420 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  145 / 200 Cost: 0.221556 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  146 / 200 Cost: 0.218686 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  147 / 200 Cost: 0.215846 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  148 / 200 Cost: 0.213227 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  149 / 200 Cost: 0.210675 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  150 / 200 Cost: 0.207877 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  151 / 200 Cost: 0.205301 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  152 / 200 Cost: 0.202941 Predict: illo_world_good_morning_see_you_hello_great
# Epoch:  153 / 200 Cost: 0.200482 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  154 / 200 Cost: 0.197940 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  155 / 200 Cost: 0.195504 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  156 / 200 Cost: 0.193312 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  157 / 200 Cost: 0.191009 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  158 / 200 Cost: 0.188609 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  159 / 200 Cost: 0.186399 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  160 / 200 Cost: 0.184273 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  161 / 200 Cost: 0.182120 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  162 / 200 Cost: 0.179918 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  163 / 200 Cost: 0.177821 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  164 / 200 Cost: 0.175825 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  165 / 200 Cost: 0.173778 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  166 / 200 Cost: 0.171743 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  167 / 200 Cost: 0.169781 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  168 / 200 Cost: 0.167870 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  169 / 200 Cost: 0.165951 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  170 / 200 Cost: 0.164041 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  171 / 200 Cost: 0.162205 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  172 / 200 Cost: 0.160384 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  173 / 200 Cost: 0.158568 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  174 / 200 Cost: 0.156787 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  175 / 200 Cost: 0.155039 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  176 / 200 Cost: 0.153317 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  177 / 200 Cost: 0.151603 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  178 / 200 Cost: 0.149919 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  179 / 200 Cost: 0.148264 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  180 / 200 Cost: 0.146624 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  181 / 200 Cost: 0.145006 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  182 / 200 Cost: 0.143410 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  183 / 200 Cost: 0.141837 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  184 / 200 Cost: 0.140278 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  185 / 200 Cost: 0.138742 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  186 / 200 Cost: 0.137231 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  187 / 200 Cost: 0.135730 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  188 / 200 Cost: 0.134249 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  189 / 200 Cost: 0.132789 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  190 / 200 Cost: 0.131348 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  191 / 200 Cost: 0.129921 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  192 / 200 Cost: 0.128508 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  193 / 200 Cost: 0.127118 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  194 / 200 Cost: 0.125743 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  195 / 200 Cost: 0.124382 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  196 / 200 Cost: 0.123036 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  197 / 200 Cost: 0.121708 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  198 / 200 Cost: 0.120395 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  199 / 200 Cost: 0.119095 Predict: lllo_world_good_morning_see_you_hello_great
# Epoch:  200 / 200 Cost: 0.117810 Predict: lllo_world_good_morning_see_you_hello_great

# %%
# Probability plot
fig, ax = plt.subplots()
fig.set_size_inches(15,20)
plt.title('Input Sequence', y=1.08, fontsize=20)
plt.xlabel('Probability of Next Character(y) Given Current One(x)', fontsize=25, y=1.5)
plt.ylabel('Character List', fontsize=20)
plot = plt.imshow(pred_act.T, cmap=plt.get_cmap('plasma'))
fig.colorbar(plot, fraction=0.015, pad=0.04)
plt.xticks(np.arange(len(char_data)-1), list(char_raw)[:-1], fontsize=15)
plt.yticks(np.arange(len(char_list)), [idx_to_char[i] for i in range(len(char_list))], fontsize=15)
ax.xaxis.tick_top()

# Annotate
for i, idx in zip(range(len(pred_out)), pred_out):
    annotation = idx_to_char[idx]
    ax.annotate(annotation, xy=(i-0.2, idx+0.2), fontsize=12)
    
plt.show()

# %% [markdown]
# ### Result:
# - 대략 55번째 Epoch에서부터 서서히 예측다운 예측이 보이기 시작함
# - 200회 Epoch에 이르기까지도 예측이 제대로 되지 않는 경우 발생 (e.g. 첫번째 문자를 'h'가 아닌 'l'로 예측)
